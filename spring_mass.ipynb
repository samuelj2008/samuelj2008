# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelj2008/samuelj2008/blob/main/spring_mass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **spring mass**

# %% [markdown]
# $F(X) = F(0) + F^\prime (0)x + \frac{1}{2}F^{\prime \prime} (0)x^2 +...= -kx + \frac{1} {2} F^ {\prime \prime} (0)x^2 +....,$

# %% [markdown]
# $Hooke'sLaw : F= -kx$

# %% [markdown]
# $Newton's 2nd Law of motion: F = ma =m(d^2x/dt^2) = mx^{\prime}$

# %% [markdown]
# $mx^{\prime \prime} =-kx$
